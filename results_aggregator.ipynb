# %% [markdown]
# ### PAD

# %%
import os
import pandas as pd

micro_res = pd.DataFrame()
macro_res = pd.DataFrame()
weighted_res = pd.DataFrame()
results = [micro_res, macro_res, weighted_res]
res_dir = '.'
metrics = ['micro avg', 'macro avg', 'weighted avg']
for subdir, dirs, files in os.walk(res_dir):
    for filename in files:
        name = ''
        if filename == 'results_aggregator.ipynb':
            continue
        if filename.find('RFQ') != -1:
            continue
        with open(os.path.join(subdir, filename)) as f:
            mode = 0
            for line in f:
                if line.find('"cell_type": "code"') != -1:
                    mode = 0
                elif line.find('"cell_type": "markdown"') != -1:
                    mode = 1
                line = line.strip().strip('"')
                if mode and line.find('##') != -1:
                    name = line.strip('#')
            
                for metric, res in zip(metrics, results):
                    if line.find(metric) != -1:
                        line = line.strip('"')
                        res.at[filename + ' ' + name, 'precision'] = line.split()[2]
                        res.at[filename + ' ' + name, 'recall'] = line.split()[3]
                        res.at[filename + ' ' + name, 'f1-score'] = line.split()[4]

# %%
micro_res.sort_values('f1-score', ascending=False)
# Out:
#                                                    precision  recall f1-score
# PAD_BERT[DeepPavlov_rubert_base_cased].ipynb           0.856   0.888    0.872
# PAD_BERT[bert_base_multilingual_cased].ipynb           0.849   0.893    0.870
# PAD_W2V_BILSTM_CRF.ipynb  SOME MORE TO COME           0.8628  0.7688   0.8131
# PAD_W2V_BILSTM_CRF.ipynb  BILSTM + CRF                0.8535  0.7512   0.7991
# PAD_BiLSTM_CRF.ipynb                                   0.915   0.706    0.797
# PAD_W2V_BILSTM_CRF.ipynb  PRETRAINED W2V              0.4957  0.8081   0.6144
# PAD_W2V_BILSTM_CRF.ipynb  NOT PRETRAINED W2V          0.3734  0.8290   0.5149
# PAD_W2V_BILSTM_CRF.ipynb  window=5, min_count=1       0.2888  0.8076   0.4255
# PAD_W2V_BILSTM_CRF.ipynb  window=5, max_vocab_s...    0.2655  0.7999   0.3987
# PAD_W2V_BILSTM_CRF.ipynb  GLOVE                       0.0964  0.5645   0.1647

# %%
macro_res.sort_values('f1-score', ascending=False)
# Out:
#                                                    precision  recall f1-score
# PAD_BERT[DeepPavlov_rubert_base_cased].ipynb           0.715   0.758    0.734
# PAD_BERT[bert_base_multilingual_cased].ipynb           0.708   0.758    0.730
# PAD_W2V_BILSTM_CRF.ipynb  BILSTM + CRF                0.7958  0.6784   0.7270
# PAD_BiLSTM_CRF.ipynb                                   0.831   0.652    0.719
# PAD_W2V_BILSTM_CRF.ipynb  SOME MORE TO COME           0.7344  0.6644   0.6954
# PAD_W2V_BILSTM_CRF.ipynb  PRETRAINED W2V              0.4683  0.6926   0.5499
# PAD_W2V_BILSTM_CRF.ipynb  NOT PRETRAINED W2V          0.3632  0.7009   0.4718
# PAD_W2V_BILSTM_CRF.ipynb  window=5, min_count=1       0.3192  0.6774   0.4209
# PAD_W2V_BILSTM_CRF.ipynb  window=5, max_vocab_s...    0.2917  0.6840   0.3946
# PAD_W2V_BILSTM_CRF.ipynb  GLOVE                       0.1538  0.4006   0.2074

# %%
weighted_res.sort_values('f1-score', ascending=False)
# Out:
#                                                    precision  recall f1-score
# PAD_BERT[DeepPavlov_rubert_base_cased].ipynb           0.857   0.888    0.870
# PAD_BERT[bert_base_multilingual_cased].ipynb           0.849   0.893    0.868
# PAD_W2V_BILSTM_CRF.ipynb  SOME MORE TO COME           0.8563  0.7688   0.8071
# PAD_W2V_BILSTM_CRF.ipynb  BILSTM + CRF                0.8463  0.7512   0.7921
# PAD_BiLSTM_CRF.ipynb                                   0.908   0.706    0.782
# PAD_W2V_BILSTM_CRF.ipynb  PRETRAINED W2V              0.5445  0.8081   0.6379
# PAD_W2V_BILSTM_CRF.ipynb  NOT PRETRAINED W2V          0.4064  0.8290   0.5371
# PAD_W2V_BILSTM_CRF.ipynb  window=5, min_count=1       0.3671  0.8076   0.4866
# PAD_W2V_BILSTM_CRF.ipynb  window=5, max_vocab_s...    0.3418  0.7999   0.4602
# PAD_W2V_BILSTM_CRF.ipynb  GLOVE                       0.1917  0.5645   0.2603

# %% [markdown]
# ### RFQ

# %%
import os
import pandas as pd

micro_res = pd.DataFrame()
macro_res = pd.DataFrame()
weighted_res = pd.DataFrame()
results = [micro_res, macro_res, weighted_res]
res_dir = '.'
metrics = ['micro avg', 'macro avg', 'weighted avg']
for subdir, dirs, files in os.walk(res_dir):
    for filename in files:
        name = ''
        if filename == 'results_aggregator.ipynb':
            continue
        if filename.find('PAD') != -1:
            continue
        with open(os.path.join(subdir, filename)) as f:
            mode = 0
            for line in f:
                if line.find('"cell_type": "code"') != -1:
                    mode = 0
                elif line.find('"cell_type": "markdown"') != -1:
                    mode = 1
                line = line.strip().strip('"')
                if mode and line.find('##') != -1:
                    name = line.strip('#')
            
                for metric, res in zip(metrics, results):
                    if line.find(metric) != -1:
                        line = line.strip('"')
                        res.at[filename + ' ' + name, 'precision'] = line.split()[2]
                        res.at[filename + ' ' + name, 'recall'] = line.split()[3]
                        res.at[filename + ' ' + name, 'f1-score'] = line.split()[4]

# %%
micro_res.sort_values('f1-score', ascending=False)
# Out:
#                                                    precision  recall f1-score
# RFQ_BiLSTM_CRF.ipynb                                   0.943   0.907    0.925
# RFQ_W2V_BILSTM_CRF.ipynb  BILSTM + CRF                0.9269  0.8479   0.8856
# RFQ_BERT[bert_base_multilingual_cased].ipynb           0.875   0.885    0.880
# RFQ_BERT[DeepPavlov_rubert_base_cased].ipynb           0.863   0.873    0.868
# RFQ_W2V_BILSTM_CRF.ipynb  window=5, max_vocab_s...    0.2166  0.1054   0.1418
# RFQ_W2V_BILSTM_CRF.ipynb  SOME MORE TO COME           0.0379  0.6077   0.0713
# RFQ_W2V_BILSTM_CRF.ipynb  PRETRAINED W2V              0.0217  0.3923   0.0411
# RFQ_W2V_BILSTM_CRF.ipynb  NOT PRETRAINED W2V          0.0000  0.0000   0.0000
# RFQ_W2V_BILSTM_CRF.ipynb  window=5, min_count=1       0.0000  0.0000   0.0000
# RFQ_W2V_BILSTM_CRF.ipynb  GLOVE                       0.0000  0.0000   0.0000

# %%
macro_res.sort_values('f1-score', ascending=False)
# Out:
#                                                    precision  recall f1-score
# RFQ_BiLSTM_CRF.ipynb                                   0.940   0.907    0.923
# RFQ_W2V_BILSTM_CRF.ipynb  BILSTM + CRF                0.9266  0.8498   0.8865
# RFQ_BERT[bert_base_multilingual_cased].ipynb           0.873   0.888    0.880
# RFQ_BERT[DeepPavlov_rubert_base_cased].ipynb           0.861   0.874    0.867
# RFQ_W2V_BILSTM_CRF.ipynb  window=5, max_vocab_s...    0.1407  0.1344   0.1375
# RFQ_W2V_BILSTM_CRF.ipynb  SOME MORE TO COME           0.0189  0.5000   0.0365
# RFQ_W2V_BILSTM_CRF.ipynb  PRETRAINED W2V              0.0108  0.5000   0.0212
# RFQ_W2V_BILSTM_CRF.ipynb  NOT PRETRAINED W2V          0.0000  0.0000   0.0000
# RFQ_W2V_BILSTM_CRF.ipynb  window=5, min_count=1       0.0000  0.0000   0.0000
# RFQ_W2V_BILSTM_CRF.ipynb  GLOVE                       0.0000  0.0000   0.0000

# %%
weighted_res.sort_values('f1-score', ascending=False)
# Out:
#                                                    precision  recall f1-score
# RFQ_BiLSTM_CRF.ipynb                                   0.943   0.907    0.925
# RFQ_W2V_BILSTM_CRF.ipynb  BILSTM + CRF                0.9269  0.8479   0.8856
# RFQ_BERT[bert_base_multilingual_cased].ipynb           0.876   0.885    0.880
# RFQ_BERT[DeepPavlov_rubert_base_cased].ipynb           0.863   0.873    0.868
# RFQ_W2V_BILSTM_CRF.ipynb  window=5, max_vocab_s...    0.1104  0.1054   0.1078
# RFQ_W2V_BILSTM_CRF.ipynb  SOME MORE TO COME           0.0230  0.6077   0.0444
# RFQ_W2V_BILSTM_CRF.ipynb  PRETRAINED W2V              0.0085  0.3923   0.0167
# RFQ_W2V_BILSTM_CRF.ipynb  NOT PRETRAINED W2V          0.0000  0.0000   0.0000
# RFQ_W2V_BILSTM_CRF.ipynb  window=5, min_count=1       0.0000  0.0000   0.0000
# RFQ_W2V_BILSTM_CRF.ipynb  GLOVE                       0.0000  0.0000   0.0000
